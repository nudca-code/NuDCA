# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().resolve().parent))

import numpy as np

from nudca import load_decay_database
from nudca import load_decay_matrix
from nudca import RadioactiveDecay, RadioactiveDecayBase

decay_database = load_decay_database(data_source='ENDF-B-VIII.1_decay')
decay_matrix = load_decay_matrix(data_source='ENDF-B-VIII.1_decay')
radioactive_decay = RadioactiveDecay( {'Kr88': 1.e-5}, decay_database, decay_matrix )

times = np.geomspace(1.e-2, 1.e3, 1000) * 86400
# Y = radioactive_decay.decay_process(1e-2 * 86400)
Y = radioactive_decay.decay_time_series(time_period=times)

print(Y)


# q = radioactive_decay.decay_heating_rates(decay_times=times)
                    # decay_heating_rates_by_type
                    # decay_heating_rates_by_nulcide
                    # decay_heating_rates_by_nuclide_and_type
# Out:
# D:\Nutstore\MYDOC\Code\Python\NuDCA\nudca\decay_matrix.py:412: RuntimeWarning: divide by zero encountered in scalar divide
#   np.log(2) / half_life_values[0] for half_life_values in decay_database.half_life_data
# D:\Nutstore\MYDOC\Code\Python\NuDCA\nudca\decay_matrix.py:190: RuntimeWarning: divide by zero encountered in scalar divide
#   decay_constant = np.log(2) / half_life
# D:\Nutstore\MYDOC\Code\Python\NuDCA\nudca\decay_matrix.py:262: RuntimeWarning: divide by zero encountered in scalar divide
#   matrix_P[i, j] = Sigma_sum / denominator
# Warning: Denominator too small for i=16 (Sg-269), j=3 (Hs-273): (-0.013862943611198907) - (-0.013862943611198907) = 0.0.
#  Setting matrix_P[16, 3] to  due to division by zero.
# Warning: Denominator too small for i=67 (Lr-260), j=39 (Db-264): (-0.003850817669777474) - (-0.003850817669777474) = 0.0.
#  Setting matrix_P[67, 39] to  due to division by zero.
# D:\Nutstore\MYDOC\Code\Python\NuDCA\nudca\decay_matrix.py:249: RuntimeWarning: invalid value encountered in scalar multiply
#   Sigma_sum += matrix_A[i, k] * matrix_P[k, j]
# Warning: Denominator too small for i=878 (Ta-188), j=877 (Hf-188): (-0.03465735902799726) - (-0.03465735902799726) = 0.0.
#  Setting matrix_P[878, 877] to  due to division by zero.
# Warning: Denominator too small for i=1017 (Os-179), j=955 (Pt-183): (-0.0017773004629742187) - (-0.0017773004629742187) = 0.0.
#  Setting matrix_P[1017, 955] to  due to division by zero.
# Warning: Denominator too small for i=1208 (Re-168), j=1135 (Ir-172): (-0.15753345012726028) - (-0.15753345012726028) = 0.0.
#  Setting matrix_P[1208, 1135] to  due to division by zero.
# Warning: Denominator too small for i=1375 (Ho-159M), j=1154 (Os-171): (-0.08351170850119823) - (-0.08351170850119823) = 0.0.
#  Setting matrix_P[1375, 1154] to  due to division by zero.
# Warning: Denominator too small for i=1465 (Lu-154), j=1463 (Hf-154): (-0.34657359027997264) - (-0.34657359027997264) = 0.0.
#  Setting matrix_P[1465, 1463] to  due to division by zero.
# Warning: Denominator too small for i=1567 (Tm-149), j=1486 (Lu-153): (-0.7701635339554948) - (-0.7701635339554948) = 0.0.
#  Setting matrix_P[1567, 1486] to  due to division by zero.
# Warning: Denominator too small for i=1528 (Yb-151), j=1527 (Yb-151M): (-0.43321698784996576) - (-0.43321698784996576) = 0.0.
#  Setting matrix_P[1528, 1527] to  due to division by zero.
# Warning: Denominator too small for i=1818 (Pm-136), j=1816 (Sm-136): (-0.014747812352339261) - (-0.014747812352339261) = 0.0.
#  Setting matrix_P[1818, 1816] to  due to division by zero.
e-06, 8.101704872568165e-06, 8.081960392366028e-06, 8.062036009897734e-06, 8.04193065791875e-06, 8.021643276522827e-06, 8.001172813559055e-06, 7.980518225057598e-06, 7.959678475664229e-06, 7.93865253908372e-06, 7.9174393985322e-06, 7.896038047198505e-06, 7.874447488714643e-06, 7.852666737635405e-06, 7.830694819927213e-06, 7.808530773466237e-06, 7.786173648545897e-06, 7.763622508393722e-06, 7.740876429697712e-06, 7.717934503142164e-06, 7.694795833953079e-06, 7.671459542453124e-06, 7.647924764626246e-06, 7.624190652691916e-06, 7.600256375689059e-06, 7.576121120069675e-06, 7.5517840903021756e-06, 7.527244509484433e-06, 7.502501619966548e-06, 7.47755468398334e-06, 7.452402984296541e-06, 7.427045824846665e-06, 7.401482531414562e-06, 7.375712452292582e-06, 7.349734958965343e-06, 7.3235494468000364e-06, 7.2971553357462255e-06, 7.270552071045063e-06, 7.243739123947861e-06, 7.216715992443928e-06, 7.189482201997585e-06, 7.162037306294251e-06, 7.134380887995498e-06, 7.1065125595029385e-06, 7.078431963730831e-06, 7.050138774887241e-06, 7.021632699263614e-06, 6.992913476032591e-06, 6.963980878053882e-06, 6.934834712688007e-06, 6.905474822617715e-06, 6.875901086676826e-06, 6.846113420686319e-06, 6.816111778297358e-06, 6.7858961518410425e-06, 6.755466573184603e-06, 6.72482311459371e-06, 6.6939658896006624e-06, 6.6628950538780555e-06, 6.6316108061176586e-06, 6.600113388914106e-06, 6.568403089653041e-06, 6.53648024140335e-06, 6.504345223813029e-06, 6.471998464008308 ...

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().resolve().parents[1]))

import os
import h5py
import numpy as np
import matplotlib.pyplot as plt

from KNdecay.radioactivedecay.decay_database import get_database
from KNdecay.radioactivedecay.decay_matrix import get_decay_matrix
from KNdecay.radioactivedecay.radioactive_decay import RadioactiveDecayBase, RadioactiveDecay
from KNdecay.radioactivedecay.nuclide import Nuclide, Z_to_element
from KNdecay.radioactivedecay.io import get_sorted_Y, filter_Y, group_and_sum


# traj_path = '/media/yolo/CQH/Data/WinNet_v1.1.6/CCSNe/Wang/model_9.5/traj_135937'
traj_path = 'G:/Data/WinNet_v1.1.6/CCSNe/Wang/model_9.5/traj_135937'

def get_Y(traj_path):
    with h5py.File(os.path.join(traj_path, 'WinNet_data.h5'), 'r') as h5file:
        time = np.array(h5file['snapshots/time'])
        A_snap = np.array(h5file['snapshots/A'])
        Z_snap = np.array(h5file['snapshots/Z'])
        Y_snaps = np.array(h5file['snapshots/Y'])
        
    return time, Y_snaps, A_snap, Z_snap


def get_nuclide_Y(nuclide, A, Z, Y):
    A_nuclide = Nuclide(nuclide).A
    Z_nuclide = Nuclide(nuclide).Z
    mask = (A==A_nuclide) & (Z==Z_nuclide)
    Y_nuclide = np.array([Y_snap[mask][0] for Y_snap in Y])
    
    return Y_nuclide


def get_heating_rate(traj_path):
    with h5py.File(os.path.join(traj_path, 'WinNet_data.h5'), 'r') as h5file:
        time = np.array(h5file['energy/time'])
        heating_rate = np.array(h5file['energy/engen_tot'])
    return time, heating_rate



decay_database = get_database('ENDF')
decay_matrix = get_decay_matrix('ENDF')

index = 220
t, Y_snap, A_snap, Z_snap = get_Y(traj_path)
Y_ini_dict = filter_Y(Z_snap, A_snap, Y_snap[index, :])


radioactive_decay = RadioactiveDecay(Y_ini_dict, decay_database, decay_matrix)
# Out:
# D:\Nutstore\MYDOC\Code\Python\RadioDecay\KNdecay\radioactivedecay\decay_matrix.py:73: RuntimeWarning: divide by zero encountered in scalar divide
#   np.log(2) / half_life_values[0] for half_life_values in decay_database.half_life_data
# D:\Nutstore\MYDOC\Code\Python\RadioDecay\KNdecay\radioactivedecay\matrix_builder.py:128: RuntimeWarning: divide by zero encountered in scalar divide
#   decay_constant = np.log(2) / half_life
# D:\Nutstore\MYDOC\Code\Python\RadioDecay\KNdecay\radioactivedecay\matrix_builder.py:202: RuntimeWarning: divide by zero encountered in scalar divide
#   matrix_P[i, j] = Sigma_sum / denominator
# D:\Nutstore\MYDOC\Code\Python\RadioDecay\KNdecay\radioactivedecay\matrix_builder.py:189: RuntimeWarning: invalid value encountered in scalar multiply
#   Sigma_sum += matrix_Lambda[i, k] * matrix_P[k, j]
# D:\Nutstore\MYDOC\Code\Python\RadioDecay\KNdecay\radioactivedecay\matrix_builder.py:202: RuntimeWarning: invalid value encountered in scalar divide
#   matrix_P[i, j] = Sigma_sum / denominator
# D:\Nutstore\MYDOC\Code\Python\RadioDecay\KNdecay\radioactivedecay\matrix_builder.py:245: RuntimeWarning: invalid value encountered in scalar subtract
#   Sigma_sum -= matrix_P[i, k] * matrix_P_inv[k, j]
# D:\Nutstore\MYDOC\Code\Python\RadioDecay\KNdecay\radioactivedecay\matrix_builder.py:245: RuntimeWarning: invalid value encountered in scalar multiply
#   Sigma_sum -= matrix_P[i, k] * matrix_P_inv[k, j]

# %%
decay_times = t[index:]

q_EM = radioactive_decay.heating_rates_by_type(decay_times, 'EM')
q_LP = radioactive_decay.heating_rates_by_type(decay_times, 'LP')
q_HP = radioactive_decay.heating_rates_by_type(decay_times, 'HP')
q = radioactive_decay.decay_heating_rates(decay_times)

fig, ax = plt.subplots(figsize=(8, 6), dpi=150)

ax.plot(decay_times, q_EM, ls='--', label=r'EM ($\gamma$-decay)')
ax.plot(decay_times, q_LP, ls='--', label=r'LP ($\beta$-decay)')
ax.plot(decay_times, q_HP, ls='--', label=r'HP ($\alpha$-decay)')
ax.plot(decay_times, q, label='Total')
ax.set_xlim(1e0, 1.e9)
ax.set_ylim(1e-5, 1e20)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Time [s]')
ax.set_ylabel('Heating Rate [erg / g / s]')

ax.legend()
plt.show()

# %%
import sys
from pathlib import Path
sys.path.insert(1, str(Path.cwd().resolve().parent))

import os
import h5py
import numpy as np
import matplotlib.pyplot as plt

from KNdecay.radioactivedecay.decay_database import get_database
from KNdecay.radioactivedecay.decay_matrix import get_decay_matrix
from KNdecay.radioactivedecay.radioactive_decay import RadioactiveDecay
from KNdecay.radioactivedecay.nuclide import Nuclide, Z_to_element
from KNdecay.radioactivedecay.io import get_sorted_Y, filter_Y, group_and_sum

traj_path = '/media/yolo/CQH/Data/WinNet_v1.1.6/CCSNe/Wang/model_9.5/traj_135937'
def get_Y(traj_path):
    with h5py.File(os.path.join(traj_path, 'WinNet_data.h5'), 'r') as h5file:
        time = np.array(h5file['snapshots/time'])
        A_snap = np.array(h5file['snapshots/A'])
        Z_snap = np.array(h5file['snapshots/Z'])
        Y_snaps = np.array(h5file['snapshots/Y'])
        
    return time, Y_snaps, A_snap, Z_snap


def get_nuclide_Y(nuclide, A, Z, Y):
    A_nuclide = Nuclide(nuclide).A
    Z_nuclide = Nuclide(nuclide).Z
    mask = (A==A_nuclide) & (Z==Z_nuclide)
    Y_nuclide = np.array([Y_snap[mask][0] for Y_snap in Y])
    
    return Y_nuclide

decay_database = get_database('ENDF')
decay_matrix = get_decay_matrix('ENDF')

index = 150
t, Y_snap, A_snap, Z_snap = get_Y(traj_path)
Y_ini_dict = filter_Y(Z_snap, A_snap, Y_snap[index, :])

radioactive_decay = RadioactiveDecay(Y_ini_dict, decay_database, decay_matrix)

times = t[index:]
results = [radioactive_decay.decay(time-t[index]) for time in times]
# Out:
# /home/yolo/NutstoreFiles/MYDOC/Code/Python/RadioDecay/KNdecay/radioactivedecay/decay_matrix.py:73: RuntimeWarning: divide by zero encountered in scalar divide
#   np.log(2) / half_life_values[0] for half_life_values in decay_database.half_life_data
# /home/yolo/NutstoreFiles/MYDOC/Code/Python/RadioDecay/KNdecay/radioactivedecay/matrix_builder.py:128: RuntimeWarning: divide by zero encountered in scalar divide
#   decay_constant = np.log(2) / half_life
# /home/yolo/NutstoreFiles/MYDOC/Code/Python/RadioDecay/KNdecay/radioactivedecay/matrix_builder.py:202: RuntimeWarning: divide by zero encountered in scalar divide
#   matrix_P[i, j] = Sigma_sum / denominator
# /home/yolo/NutstoreFiles/MYDOC/Code/Python/RadioDecay/KNdecay/radioactivedecay/matrix_builder.py:189: RuntimeWarning: invalid value encountered in scalar multiply
#   Sigma_sum += matrix_Lambda[i, k] * matrix_P[k, j]
# /home/yolo/NutstoreFiles/MYDOC/Code/Python/RadioDecay/KNdecay/radioactivedecay/matrix_builder.py:202: RuntimeWarning: invalid value encountered in scalar divide
#   matrix_P[i, j] = Sigma_sum / denominator
# /home/yolo/NutstoreFiles/MYDOC/Code/Python/RadioDecay/KNdecay/radioactivedecay/matrix_builder.py:245: RuntimeWarning: invalid value encountered in scalar subtract
#   Sigma_sum -= matrix_P[i, k] * matrix_P_inv[k, j]
# /home/yolo/NutstoreFiles/MYDOC/Code/Python/RadioDecay/KNdecay/radioactivedecay/matrix_builder.py:245: RuntimeWarning: invalid value encountered in scalar multiply
#   Sigma_sum -= matrix_P[i, k] * matrix_P_inv[k, j]
# /home/yolo/NutstoreFiles/MYDOC/Code/Python/RadioDecay/KNdecay/radioactivedecay/radioactive_decay.py:89: RuntimeWarning: invalid value encountered in multiply
#   -decay_time * self.decay_matrix.decay_constants[indices]

# %%
nuclides = ['Ni-56', 'Co-56',
            'Ge-64', 'Ga-64',
            'Zn-60', 'Cu-60']

# # nuclides = ['Cu-64', 'Ni-64', 'Zn-64']
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown']

fig, ax = plt.subplots(figsize=(8, 6), dpi=150)
for nuclide, color in zip(nuclides, colors):
    Y_nuc = [result.nuclide_abundance[f'{nuclide}'] for result in results]
    Y_net = get_nuclide_Y(nuclide, A_snap, Z_snap, Y_snap)
    ax.plot(times, Y_nuc, ls='-', color=color, label=f'{nuclide}')
    ax.plot(t[index:], Y_net[index:], ls='--', color=color)

ax.set_xlim(1e0, 1.e9)
ax.set_ylim(1e-10, 1e-2)
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Time [s]')
ax.set_ylabel('Y')
ax.set_title('Dashed lines: WinNet\nSolid lines: Chains')

ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # <center> Solar Abundance </center>

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().resolve().parent))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from nudca import load_decay_database
from nudca import load_decay_matrix
from nudca import RadioactiveDecay
from nudca.io import filter_Y, to_dict


decay_database = load_decay_database(data_source='ENDF-B-VIII.1_decay')
decay_matrix = load_decay_matrix(data_source='ENDF-B-VIII.1_decay')

df_solar = pd.read_excel(Path.cwd().resolve().parent.joinpath('nudca/data/solar_r_abundance_pattern.xlsx'))
# Y_ini_dict = filter_Y(df_solar['Z'], df_solar['A'], df_solar['Y'])
Y_ini_dict = to_dict(df_solar['Z'], df_solar['A'], df_solar['Y'])
radioactive_decay = RadioactiveDecay(Y_ini_dict, decay_database, decay_matrix)

decay_times = np.geomspace(1.e-2, 5.e2, 1000) * 86400
q_EM = radioactive_decay.heating_rates_by_type(decay_times, 'EM')
q_LP = radioactive_decay.heating_rates_by_type(decay_times, 'LP')
# q_HP = radioactive_decay.heating_rates_by_type(decay_times, 'HP')
q = radioactive_decay.decay_heating_rates(decay_times)


df_hotokezaka = pd.read_csv(Path.cwd().resolve().parent.joinpath('data/heat85_209_M005_v04_v1_n45.dat'), sep='\s+', header=None)
t_hotokezaka = df_hotokezaka[0].values
q_tot_hotokezaka = df_hotokezaka[1].values
q_gamma_hotokezaka = df_hotokezaka[2].values
q_e_hotokezaka = df_hotokezaka[3].values
q_gamma_th_hotokezaka = df_hotokezaka[4].values
q_e_th_hotokezaka = df_hotokezaka[5].values
# Out:
# <>:30: SyntaxWarning: invalid escape sequence '\s'
# <>:30: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_11245/652177939.py:30: SyntaxWarning: invalid escape sequence '\s'
#   df_hotokezaka = pd.read_csv(Path.cwd().resolve().parent.joinpath('data/heat85_209_M005_v04_v1_n45.dat'), sep='\s+', header=None)

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(18, 6), sharex=True, sharey=True, dpi=150)

axs[0].plot(decay_times/86400, q_EM, ls='-', lw=3, color='b')
axs[0].plot(t_hotokezaka, q_gamma_hotokezaka, ls='--', lw=3, color='r')
axs[0].set_xlim(1e-1, 5.e2)
axs[0].set_ylim(1e5, 1e12)
axs[0].set_xscale('log')
axs[0].set_yscale('log')
axs[0].set_xlabel('Time [days]')
axs[0].set_ylabel('Heating Rate [erg / g / s]')

axs[1].plot(decay_times/86400, q_LP, ls='-', lw=3, color='b')
axs[1].plot(t_hotokezaka, q_e_hotokezaka, ls='--', lw=3, color='r')
axs[1].set_xlabel('Time [days]')

axs[2].plot(decay_times/86400, q, ls='-', lw=3, color='b', label='NuDCA')
axs[2].plot(t_hotokezaka, q_tot_hotokezaka, ls='-', lw=3, color='r', label='Hotokezaka et al. (2020)')
axs[2].set_xlabel('Time [days]')


axs[0].text(2.e-1, 1.e7, r'$\beta^{-}$ decay: $\gamma$', fontsize=12)
axs[1].text(2.e-1, 1.e7, r'$\beta^{-}$ decay: $e^{-}$', fontsize=12)
axs[2].text(2.e-1, 1.e7, r'$\beta^{-}$ decay: Total', fontsize=12)

axs[2].legend()
plt.tight_layout()
plt.show()

# %%
# Out:
# 50

# %%
# Out:
# -94500
